# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import tweepy
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import os
import requests
import seaborn as sns

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20,20)

# %% [markdown]
# ---------------------------------------------------------------
# <br>
#
# ### Data Gathering:
#
# - Importing twitter-archive-enhanced csv file.
# - Importing image_predections using `requests`.
# - Importing tweet_json.

# %%
twitter_enhanced = pd.read_csv("twitter-archive-enhanced.csv")

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# %%
with open(os.path.join('image_predictions.tsv'), mode = 'wb') as file:
    file.write(response.content)

# %%
image_pred = pd.read_csv('image_predictions.tsv', sep='\t')

# %%
consumer_key = 'X'
consumer_secret = 'X'
access_token = 'X'
access_secret = 'X'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
twitter = pd.read_json('tweet_json.txt')

# %% [markdown]
# ---------------------------------------------------------------
# <br> <br>
#
# ### Data Assesing
#
# - Dataset: twitter_enhanced

# %%
twitter_enhanced.sample(4)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1150  726224900189511680                    NaN                  NaN
# 893   759446261539934208                    NaN                  NaN
# 1532  690005060500217858                    NaN                  NaN
# 1391  700143752053182464                    NaN                  NaN
#
#                       timestamp  \
# 1150  2016-04-30 01:41:23 +0000
# 893   2016-07-30 17:51:13 +0000
# 1532  2016-01-21 02:56:40 +0000
# 1391  2016-02-18 02:24:13 +0000
#
#                                                  source  \
# 1150  <a href="http://twitter.com/download/iphone" r...
# 893   <a href="http://twitter.com/download/iphone" r...
# 1532  <a href="http://twitter.com/download/iphone" r...
# 1391  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1150  I'm getting super heckin frustrated with you a...                  NaN
# ...

# %%
twitter_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
twitter_enhanced.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
twitter_enhanced.nunique()
# Out:
# tweet_id                      2356
# in_reply_to_status_id           77
# in_reply_to_user_id             31
# timestamp                     2356
# source                           4
# text                          2356
# retweeted_status_id            181
# retweeted_status_user_id        25
# retweeted_status_timestamp     181
# expanded_urls                 2218
# rating_numerator                40
# rating_denominator              18
# name                           957
# doggo                            2
# floofer                          2
# pupper                           2
# puppo                            2
# dtype: int64

# %%
twitter_enhanced['source'].value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
twitter_enhanced['rating_numerator'].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
twitter_enhanced['rating_denominator'].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
twitter_enhanced['name'].value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Oliver      11
# Lucy        11
#           ...
# Nigel        1
# Tove         1
# Gabby        1
# Grey         1
# Traviss      1
# Name: name, Length: 957, dtype: int64

# %%
twitter_enhanced.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
twitter_enhanced.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', 'None', 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver',
#        'Jim', 'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'such',
#        'Maya', 'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey',
#        'Lilly', 'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella',
#        'Grizzwald', 'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey',
#        'Gary', 'a', 'Elliot', 'Louis', 'Jesse', 'Romeo', 'Bailey',
#        'Duddles', 'Jack', 'Emmy', 'Steven', 'Beau', 'Snoopy', 'Shadow',
#        'Terrance', 'Aja', 'Penny', 'Dante', 'Nelly', 'Ginger', 'Benedict',
#        'Venti', 'Goose', 'Nugget', 'Cash', 'Coco', 'Jed', 'Sebastian',
#        'Walter', 'Sierra', 'Monkey', 'Harry', 'Kody', 'Lassie', 'Rover',
#        'Napolean', 'Dawn', 'Boomer', 'Cody', 'Rumble', 'Clifford',
#        'quite', 'Dewey', 'Scout', 'Gizmo', 'Cooper', 'Harold', 'Shikha',
# ...

# %%
twitter_enhanced.loc[twitter_enhanced.name.str.isupper()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 775   776201521193218049                    NaN                  NaN
# 2041  671542985629241344                    NaN                  NaN
#
#                       timestamp  \
# 775   2016-09-14 23:30:38 +0000
# 2041  2015-12-01 04:14:59 +0000
#
#                                                  source  \
# 775   <a href="http://twitter.com/download/iphone" r...
# 2041  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 775   This is O'Malley. That is how he sleeps. Doesn...                  NaN
# 2041  This is JD (stands for "just dog"). He's like ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 775                        NaN                        NaN
# 2041                       NaN                        NaN
#
# ...

# %%
twitter_enhanced.loc[twitter_enhanced.name.str.islower()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 22    887517139158093824                    NaN                  NaN
# 56    881536004380872706                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# 169   859196978902773760                    NaN                  NaN
# 193   855459453768019968                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2349  666051853826850816                    NaN                  NaN
# 2350  666050758794694657                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
#
#                       timestamp  \
# 22    2017-07-19 03:39:09 +0000
# 56    2017-07-02 15:32:16 +0000
# 118   2017-05-31 18:47:24 +0000
# ...

# %%
len(twitter_enhanced.loc[(twitter_enhanced['doggo']== 'doggo') & (twitter_enhanced['floofer']== 'floofer')])
# Out:
# 1

# %%
len(twitter_enhanced.loc[(twitter_enhanced['doggo']== 'doggo') & (twitter_enhanced['pupper']== 'pupper')])
# Out:
# 12

# %%
len(twitter_enhanced.loc[(twitter_enhanced['doggo']== 'None') & (twitter_enhanced['floofer']== 'None') & (twitter_enhanced['pupper']== 'None') & (twitter_enhanced['puppo']== 'None')])
# Out:
# 1976

# %%
len(twitter_enhanced.loc[(twitter_enhanced['floofer']== 'floofer') & (twitter_enhanced['pupper']== 'pupper')])
# Out:
# 0

# %%
twitter_enhanced.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %% [markdown]
# -----------------------
# - Dataset: Twitter

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2345 entries, 0 to 2344
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2345 non-null   datetime64[ns, UTC]
#  1   id                             2345 non-null   int64
#  2   id_str                         2345 non-null   int64
#  3   full_text                      2345 non-null   object
#  4   truncated                      2345 non-null   bool
#  5   display_text_range             2345 non-null   object
#  6   entities                       2345 non-null   object
#  7   extended_entities              2069 non-null   object
#  8   source                         2345 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     float64
#  11  in_reply_to_user_id            78 non-null     float64
# ...

# %%
twitter.sample(4)
# Out:
#                     created_at                  id              id_str  \
# 399  2017-01-23 17:20:14+00:00  823581115634085888  823581115634085888
# 48   2017-07-06 00:46:41+00:00  882762694511734784  882762694511734784
# 1432 2016-02-08 17:17:22+00:00  696744641916489729  696744641916489728
# 588  2016-11-16 00:38:54+00:00  798686750113755136  798686750113755136
#
#                                               full_text  truncated  \
# 399   This is Crawford. He's quite h*ckin good at th...      False
# 48    This is Gus. He's quite the cheeky pupper. Alr...      False
# 1432  This is Klevin. He doesn't want his family bra...      False
# 588   RT @dog_rates: Say hello to Jack (pronounced "...      False
#
#      display_text_range                                           entities  \
# 399            [0, 106]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 48             [0, 114]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
twitter['id'].duplicated().any()
# Out:
# False

# %%
twitter.describe()
# Out:
#                  id        id_str  in_reply_to_status_id  \
# count  2.345000e+03  2.345000e+03           7.800000e+01
# mean   7.422940e+17  7.422940e+17           7.455079e+17
# std    6.833642e+16  6.833642e+16           7.582492e+16
# min    6.660209e+17  6.660209e+17           6.658147e+17
# 25%    6.783802e+17  6.783802e+17           6.757419e+17
# 50%    7.189392e+17  7.189392e+17           7.038708e+17
# 75%    7.986979e+17  7.986979e+17           8.257804e+17
# max    8.924206e+17  8.924206e+17           8.862664e+17
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               7.800000e+01         7.800000e+01
# mean                7.455079e+17         2.014171e+16
# std                 7.582492e+16         1.252797e+17
# min                 6.658147e+17         1.185634e+07
# 25%                 6.757419e+17         3.086374e+08
# 50%                 7.038708e+17         4.196984e+09
# 75%                 8.257804e+17         4.196984e+09
# ...

# %% [markdown]
# ------------------------------------
# - Dataset: image_pred

# %%
image_pred.sample(4)
# Out:
#                 tweet_id                                          jpg_url  \
# 760   688828561667567616  https://pbs.twimg.com/media/CY816snW8AYltrQ.jpg
# 1206  742150209887731712  https://pbs.twimg.com/media/CkylrVWWsAAiXJE.jpg
# 256   670764103623966721  https://pbs.twimg.com/media/CU8IY0pWIAA2AJ-.jpg
# 1578  796149749086875649  https://pbs.twimg.com/media/Cwx99rpW8AMk_Ie.jpg
#
#       img_num                p1   p1_conf  p1_dog                  p2  \
# 760         1          Cardigan  0.614231    True               skunk
# 1206        1       Siamese_cat  0.112413   False      French_bulldog
# 256         1   Norfolk_terrier  0.172850    True    golden_retriever
# 1578        1  golden_retriever  0.600276    True  Labrador_retriever
#
#        p2_conf  p2_dog             p3   p3_conf  p3_dog
# 760   0.139392   False  toilet_tissue  0.031158   False
# 1206  0.071414    True            hog  0.062465   False
# 256   0.072702    True     television  0.037494   False
# ...

# %%
image_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_pred['tweet_id'].duplicated().any()
# Out:
# False

# %%
image_pred['img_num'].value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
image_pred['p1_dog'].value_counts()
# Out:
# True     1532
# False     543
# Name: p1_dog, dtype: int64

# %%
image_pred['p2_dog'].value_counts()
# Out:
# True     1553
# False     522
# Name: p2_dog, dtype: int64

# %%
image_pred['p3_dog'].value_counts()
# Out:
# True     1499
# False     576
# Name: p3_dog, dtype: int64

# %% [markdown]
# ----------------------------------------
#
#
# ## Quality Issues:
#
# #### Dataset twitter_enhanced:
#
# - There are unnecessary columns.
# - There are retweets.
# - `expanded_urls` column: tweets/ retweets without images
# - `timestamp` is not in datetime format
# - `name` has missing data but not NaN, and some names are wrong.
# - `tweet_id` should be in type object.
# - Some tweets include more than one rating with decimal numbers.
# - `pupper`, `puppo`, `floofer` and `doggo` columns: For 1976 IDs there is no dog "stage" information.
# - `pupper`, `puppo`, `floofer` and `doggo` columns: There are some IDs with more than one dog "stage" information (two dogs are rated).
#
# #### Dataset twitter:
#
# - `id` should be type object.
#
# #### Dataset image_pred:
#
# - Dog breeds are not lower or uppercase always.
# - `tweet_id` should be type object.
# - `img_num` column isn't needed
# ----------------------------------------

# %% [markdown]
# -------------------------------
#
# ## Tidiness Issues:
#
# - twitter_enhanced: Transform the 4 columns `dogger`, `floofer`, `pupper` and `puppo` into one variable `stage`.
# - image_pred: the prediction shall be collected in only one column `breed_pred`
# - image_pred: the prediction confidence should be collected int one column `pred_confidence`
# - image_pred: `jpg_url`, `breed_pred` and `pred_confidence` should be in one table `twitter_enhanced`.
# - twitter: `favorite_count` and `retweet_count` column should be in one table, `twitter_enhanced` Dataset.
#
# ----------------------------

# %% [markdown]
# ----------------------------
# ### Data Cleaning:

# %%
twitter_enhanced_clean = twitter_enhanced.copy()
twitter_clean = twitter.copy()
image_pred_clean = image_pred.copy()

# %% [markdown]
# ### First: Quality Issues
#
# ##### Merging all sets together in order to do clean only once. (TIDINESS ISSUE) (1)

# %%
df = pd.concat([twitter_enhanced_clean, image_pred_clean, twitter_clean], join='outer', axis=1)

# %%
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'created_at', 'id',
#        'id_str', 'full_text', 'truncated', 'display_text_range', 'entities',
#        'extended_entities', 'source', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo',
#        'coordinates', 'place', 'contributors', 'is_quote_status',
#        'retweet_count', 'favorite_count', 'favorited', 'retweeted',
#        'possibly_sensitive', 'possibly_sensitive_appealable', 'lang',
# ...

# %% [markdown]
# ### DEFINE
# -  Deleting retweets details. (1)
#
# **CODE:**

# %%
df = df[np.isnan(df.retweeted_status_id)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 60 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tweet_id                       2175 non-null   int64
#  1   in_reply_to_status_id          78 non-null     float64
#  2   in_reply_to_user_id            78 non-null     float64
#  3   timestamp                      2175 non-null   object
#  4   source                         2175 non-null   object
#  5   text                           2175 non-null   object
#  6   retweeted_status_id            0 non-null      float64
#  7   retweeted_status_user_id       0 non-null      float64
#  8   retweeted_status_timestamp     0 non-null      object
#  9   expanded_urls                  2117 non-null   object
#  10  rating_numerator               2175 non-null   int64
#  11  rating_denominator             2175 non-null   int64
# ...

# %%
df.drop(['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'], axis=1, inplace=True)

# %% [markdown]
# **TEST:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 57 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tweet_id                       2175 non-null   int64
#  1   in_reply_to_status_id          78 non-null     float64
#  2   in_reply_to_user_id            78 non-null     float64
#  3   timestamp                      2175 non-null   object
#  4   source                         2175 non-null   object
#  5   text                           2175 non-null   object
#  6   expanded_urls                  2117 non-null   object
#  7   rating_numerator               2175 non-null   int64
#  8   rating_denominator             2175 non-null   int64
#  9   name                           2175 non-null   object
#  10  doggo                          2175 non-null   object
#  11  floofer                        2175 non-null   object
# ...

# %% [markdown]
# ### DEFINE
# - Deleting unnecessary columns (2)
#
# **CODE:**

# %%
df.drop(['in_reply_to_status_id', 'in_reply_to_user_id','source'], axis = 1, inplace=True)

# %%
df.drop(['in_reply_to_status_id_str', 'in_reply_to_user_id_str','in_reply_to_screen_name'], axis=1, inplace=True)

# %%
df.drop(['retweeted_status'], axis = 1, inplace=True)

# %%
df = df.loc[:,~df.columns.duplicated()]

# %% [markdown]
# **TEST:**

# %%
df.columns
# Out:
# Index(['tweet_id', 'timestamp', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'created_at', 'id', 'id_str',
#        'full_text', 'truncated', 'display_text_range', 'entities',
#        'extended_entities', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'possibly_sensitive',
#        'possibly_sensitive_appealable', 'lang', 'quoted_status_id',
#        'quoted_status_id_str', 'quoted_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tweet_id                       2175 non-null   int64
#  1   timestamp                      2175 non-null   object
#  2   text                           2175 non-null   object
#  3   expanded_urls                  2117 non-null   object
#  4   rating_numerator               2175 non-null   int64
#  5   rating_denominator             2175 non-null   int64
#  6   name                           2175 non-null   object
#  7   doggo                          2175 non-null   object
#  8   floofer                        2175 non-null   object
#  9   pupper                         2175 non-null   object
#  10  puppo                          2175 non-null   object
#  11  jpg_url                        1896 non-null   object
# ...

# %% [markdown]
# ### DEFINE
# - Convert `timestamps` to datetime type (3)
#
# **CODE:**

# %%
df['timestamp'] = df['timestamp'].str.slice(start=0, stop=-6)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], format = "%Y-%m-%d %H:%M:%S")

# %% [markdown]
# **TEST:**

# %%
df.timestamp
# Out:
# 0      2017-08-01 16:23:56
# 1      2017-08-01 00:17:27
# 2      2017-07-31 00:18:03
# 3      2017-07-30 15:58:51
# 4      2017-07-29 16:00:24
#                ...
# 2351   2015-11-16 00:24:50
# 2352   2015-11-16 00:04:52
# 2353   2015-11-15 23:21:54
# 2354   2015-11-15 23:05:30
# 2355   2015-11-15 22:32:08
# Name: timestamp, Length: 2175, dtype: datetime64[ns]

# %% [markdown]
# ### DEFINE:
# - remove wrong names (4)
#
# **CODE:**

# %%
df.name = df.name.str.replace('^[a-z]+', 'None')

# %% [markdown]
# **TEST:**

# %%
df.name.value_counts()
# Out:
# None       784
# Charlie     11
# Lucy        11
# Cooper      10
# Oliver      10
#           ...
# Mo           1
# Dallas       1
# Saydee       1
# Remus        1
# Godi         1
# Name: name, Length: 931, dtype: int64

# %% [markdown]
# ### DEFINE:
# - Change Tweet_id int to object. (5)
#
# **CODE:**

# %%
df['tweet_id'] = df['tweet_id'].astype('str')

# %% [markdown]
# **TEST**

# %%
df.tweet_id
# Out:
# 0       892420643555336193
# 1       892177421306343426
# 2       891815181378084864
# 3       891689557279858688
# 4       891327558926688256
#                ...
# 2351    666049248165822465
# 2352    666044226329800704
# 2353    666033412701032449
# 2354    666029285002620928
# 2355    666020888022790149
# Name: tweet_id, Length: 2175, dtype: object

# %% [markdown]
# ### DEFINE:
#
# - Unstandardized ratings, Calculate the value of the `numerator` divided by the `denominator` as`rating`. (6)
#
# **CODE:**

# %%
df['rating'] = df['rating_numerator'] / df['rating_denominator']

# %% [markdown]
# **TEST**

# %%
df.rating
# Out:
# 0       1.3
# 1       1.3
# 2       1.2
# 3       1.3
# 4       1.2
#        ...
# 2351    0.5
# 2352    0.6
# 2353    0.9
# 2354    0.7
# 2355    0.8
# Name: rating, Length: 2175, dtype: float64

# %% [markdown]
# ### DEFINE:
#
# - Standardize dog ratings.
#
# **CODE**

# %% [markdown]
# ### DEFINE:
#
# - Text cut off, Change table display settings. (8)

# %%
df.rename(columns={'rating_numerator': 'numerator', 
                    'rating_denominator': 'denominator'}, 
          inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# **TEST**

# %%
df.sample(1)
# Out:
#                 tweet_id           timestamp  \
# 1524  690597161306841088 2016-01-22 18:09:28
#
#                                                    text  \
# 1524  This is Lolo. She's America af. Behind in scie...
#
#                                           expanded_urls  numerator  \
# 1524  https://twitter.com/dog_rates/status/690597161...         11
#
#       denominator  name doggo floofer pupper puppo  \
# 1524           10  Lolo  None    None   None  None
#
#                                               jpg_url  img_num       p1  \
# 1524  https://pbs.twimg.com/media/CvAr88kW8AEKNAO.jpg      2.0  Samoyed
#
#       p1_conf p1_dog          p2   p2_conf p2_dog          p3   p3_conf  \
# 1524  0.73548   True  Pomeranian  0.075101   True  Arctic_fox  0.036072
#
#      p3_dog                created_at            id        id_str  \
# 1524  False 2016-01-21 01:07:23+00:00  6.899776e+17  6.899776e+17
#
#                                               full_text truncated  \
# ...

# %% [markdown]
# -------------------
# ### Second: Tidiness Issues

# %% [markdown]
# ### DEFINE:
#
# - make one column for dog stage (2)
# - Getting ride of multiple staging.
#
# **CODE:**

# %%
df['dog_stage'] = df['text'].str.extract('(doggo|floofer|pupper|puppo)')

# %%
df.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1, inplace=True)

# %% [markdown]
# **TEST**

# %%
df.dog_stage.value_counts()
# Out:
# pupper     244
# doggo       84
# puppo       32
# floofer      4
# Name: dog_stage, dtype: int64

# %% [markdown]
# df.info()

# %% [markdown]
# ### DEFINE:
#
# - Create a new colum `breed_pred`, The dog breed prediction and prediction confidence should be packed into one column. (3)

# %%
def return_breed(row):
    if row['p1_dog']:
        return(row['p1'])
    elif row['p2_dog']:
        return(row['p2'])
    elif row['p3_dog']:
        return(row['p3'])
    else:
        return(np.NaN)
    
def return_confidence(row):
    if row['p1_dog']:
        return(row['p1_conf'])
    elif row['p2_dog']:
        return(row['p2_conf'])
    elif row['p3_dog']:
        return(row['p3_conf'])
    else:
        return(np.NaN)

# %%
df['breed_pred'] = df.apply (lambda row: return_breed (row),axis=1)

# %%
df['pred_confidence'] = df.apply (lambda row: return_confidence(row),axis=1)

# %% [markdown]
# **TEST**

# %%
df.breed_pred.value_counts()
# Out:
# golden_retriever      165
# Labrador_retriever    102
# Chihuahua              88
# Pembroke               85
# pug                    63
#                      ...
# Japanese_spaniel        1
# Irish_wolfhound         1
# Scottish_deerhound      1
# clumber                 1
# groenendael             1
# Name: breed_pred, Length: 112, dtype: int64

# %%
df.pred_confidence.value_counts()
# Out:
# 0.593858    2
# 0.363272    2
# 0.272205    2
# 0.500509    2
# 0.274637    2
#            ..
# 0.996952    1
# 0.848735    1
# 0.207281    1
# 0.584580    1
# 0.931120    1
# Name: pred_confidence, Length: 1552, dtype: int64

# %% [markdown]
# ### DEFINE:
#
# - Dog breeds are not always lower or upper case. (Quality Issues 8)
#
# **CODE**

# %%
df.breed_pred = df.breed_pred.str.lower()

# %% [markdown]
# **TEST**

# %%
df.breed_pred.str.isupper().any()
# Out:
# False

# %% [markdown]
# ----------------
#
#
# ## Analyzing and Visualizing Data:

# %%
sns.lmplot(x="retweet_count", 
           y="favorite_count", 
           data=df,
           size = 5,
           aspect=1.3,
           scatter_kws={'alpha':1/5})

plt.xlabel('Retweet Count')
plt.ylabel('Favourite Count');
# Out:
# C:\Users\Jabal\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - `Favourite` and `retweet` counts are positively correlated.
# - The majority of the data falls below 40000 favorites and 10000 retweets.

# %%
df['breed_pred'].value_counts().plot(kind = 'barh')
plt.title('Top Rated Dog Breed')
plt.xlabel('Count')
plt.ylabel('Breed of dog');

# %% [markdown]
# Visualisation above shows the most frequent dog breed in the dataset, which is golden retriever.

# %%
df.name.value_counts()[1:8].plot(title='Most frequent Dog Names').set_xlabel("Number of Dogs");

# %% [markdown]
# Most frequent names are shown, `Charlie`,`Lucy` and `Cooper`.

# %% [markdown]
# ### Storing Wrangled Data

# %%
df.to_csv('twitter_archive_master.csv')
